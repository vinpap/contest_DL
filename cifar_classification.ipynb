# %% [markdown]
# # CIFAR Classification
#
# ### Exercise objectives
#
# - Implement a CNN for a 10-class classification problem
# - Enhance the CNN performance with data augmentation techniques
# - Experiment the acceleration of GPU for image processing (Google Colab)
#
# <hr>
# <hr>
#
# You should now have a better feeling of how a CNN is working, and especially how the convolutions are affecting the image to detect specific features. Therefore, let's now play with a bit more complex images.
#
# The CIFAR-10 dataset is a dataset that contains images of 10 different classes
#
# <img src="https://people.minesparis.psl.eu/fabien.moutarde/ES_MachineLearning/mini-projets/cifar10_notebook_fichiers/cifar_10.png">
#
# This dataset is emblematic in the research community as many enhancements for image problems have been achieved on this dataset, and later on the CIFAR-100 dataset once the performance got too high. You can check the [wikipedia](https://en.wikipedia.org/wiki/CIFAR-10) page of the dataset if you want to know more about it.
#
# In this notebook, we propose to implement a CNN to distinguish the 10 categories from the CIFAR-10 dataset. Again, remember that until 10 years ago, this problem was very challenging to the entire research community and is now for you to tackle.

# %% [markdown]
# ## 0. Colab
#
# **First, make sure to use GPU acceleration** by clicking on `"Runtime --> Change runtime --> GPU"` if you are on Colab.

# %% [markdown]
# ## 1. Data
#
# We'll take care of data loading and preprocessing for you. Just run the following cells and make sure you understand them

# %%
import time
from tensorflow.keras.datasets import cifar10
import numpy as np

(images_train, labels_train), (images_test, labels_test) = cifar10.load_data()
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %% [markdown]
# ❗️ 50,000 images may take a long time to train: **Always start with a subsample to iterate quickly** before scaling up
#
# Below, we divide the dataset size by `reduction_factor=10`. Don't try to increase it unless we ask you too.

# %%
t1 = time.time()
# Reduce size
reduction_factor = 10

idx_train =  np.random.choice(len(images_train), round(len(images_train)/reduction_factor))
idx_test =  np.random.choice(len(images_test), round(len(images_test)/reduction_factor))

images_train_small = images_train[idx_train]
images_test_small = images_test[idx_test]
labels_train_small = labels_train[idx_train]
labels_test_small = labels_test[idx_test]

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train_small, return_counts=True)
dict(zip(unique, counts))
t2 = time.time()
print(f"Execution time: {t2-t1} s")
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# Execution time: 0.008358478546142578 s

# %%
# Let's plot few images to see what they look like
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(6):
    plt.subplot(1,6, i+1)
    img = images_train[i]
    label = labels_train[i][0]
    plt.imshow(img)
    plt.title(labels[label])

# %% [markdown]
# And, as usual,
# - we normalize the data between 0 and 1
# - we create `y` as one-hot-encoded version of `labels`

# %%
X_train = images_train / 255.
X_train_small = images_train_small / 255.
X_test = images_test / 255.
X_test_small = images_test_small / 255.

from tensorflow.keras.utils import to_categorical
y_train = to_categorical(labels_train, 10)
y_train_small = to_categorical(labels_train_small, 10)
y_test = to_categorical(labels_test, 10)
y_test_small = to_categorical(labels_test_small, 10)

# %% [markdown]
# ## 2. Iterate on your CNN architecture using your small training set
#
#
# ❓ **Question** ❓ Your turn to shine!
#
# - Define the CNN architecture of your choice in a method `initialize_model()`
# - Compile your model in a method `compile_model()`:
# - Fit it on your **small** training set **only**
# - Store the output of the fit in an `history` variable
# - Try a first model yourself, before looking at PRO TIPS below
#
# <details>
#     <summary> 🆘 PRO TIPS 🆘  </summary>
#
#
# - Do not forget to add the input shape of your data to the first layer: it has 3 colors
# - Start simple, complexify after few trials to get better results
# - The task is complex: Try at least 3 or 4 convolutions
# - Kernel size do not need to be large for such small picture resolution!
# - Add some Maxpooling (but not too much else the activation "image" will become too small)
# - Keep padding = 'same' and 'stride' = (1,1) to start with.
# - Once your model overfits, try adding some dropout layer to regularize the network. A good tip is too increase dropout strengh as you move closer to the output, so as not to overfit on your end-result
# - Images are so small, that you can use larger batch size (32 or 64) to benefit from even more GPU parallelization
# </details>

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam


def initialize_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    model = Sequential()
    ### First convolution & max-pooling
    model.add(Conv2D(16, 6, input_shape=(32, 32, 3), activation="relu", padding="same"))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    ### Second convolution & max-pooling
    model.add(Conv2D(16, 4, activation="relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    ### Flattening
    model.add(Flatten())

    ### One fully connected
    model.add(Dense(16, activation="relu"))

    ### Last layer (let's say a classification with 10 output)
    model.add(Dense(10, activation="softmax"))
    
    return model

# %%
def compile_model(model):
    '''return a compiled model suited for the cifar tasks'''

    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback = EarlyStopping(patience=5, restore_best_weights=True)
model = initialize_model()
model = compile_model(model)
print(model.summary())

t1 = time.time()
history = model.fit(X_train_small, 
                    y_train_small, 
                    batch_size=32, 
                    epochs=50, 
                    validation_split=0.3,
                    callbacks=[callback], 
                    verbose=1)

t2 = time.time()
print(f"Execution time: {t2-t1} s")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)        1744
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 16)        4112
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 16)                9232
#
#  dense_1 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 15,258
# Trainable params: 15,258
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 110/110 [==============================] - 9s 9ms/step - loss: 2.2459 - accuracy: 0.1443 - val_loss: 2.1152 - val_accuracy: 0.2107
# Epoch 2/50
# 110/110 [==============================] - 1s 5ms/step - loss: 2.0544 - accuracy: 0.2271 - val_loss: 2.0332 - val_accuracy: 0.2473
# Epoch 3/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.8471 - accuracy: 0.3140 - val_loss: 1.7883 - val_accuracy: 0.3433
# Epoch 4/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.7206 - accuracy: 0.3703 - val_loss: 1.7800 - val_accuracy: 0.3640
# Epoch 5/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.6619 - accuracy: 0.3997 - val_loss: 1.6939 - val_accuracy: 0.3800
# Epoch 6/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5928 - accuracy: 0.4206 - val_loss: 1.7148 - val_accuracy: 0.3727
# Epoch 7/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5093 - accuracy: 0.4474 - val_loss: 1.6612 - val_accuracy: 0.3973
# Epoch 8/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4977 - accuracy: 0.4560 - val_loss: 1.6696 - val_accuracy: 0.3960
# Epoch 9/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.4429 - accuracy: 0.4771 - val_loss: 1.6851 - val_accuracy: 0.3960
# Epoch 10/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3991 - accuracy: 0.4960 - val_loss: 1.6322 - val_accuracy: 0.4140
# Epoch 11/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3668 - accuracy: 0.5140 - val_loss: 1.6030 - val_accuracy: 0.4247
# Epoch 12/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3266 - accuracy: 0.5186 - val_loss: 1.6189 - val_accuracy: 0.4160
# Epoch 13/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2893 - accuracy: 0.5420 - val_loss: 1.6008 - val_accuracy: 0.4213
# Epoch 14/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2688 - accuracy: 0.5469 - val_loss: 1.6072 - val_accuracy: 0.4333
# Epoch 15/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2581 - accuracy: 0.5517 - val_loss: 1.6028 - val_accuracy: 0.4287
# Epoch 16/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1916 - accuracy: 0.5789 - val_loss: 1.5825 - val_accuracy: 0.4500
# Epoch 17/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1724 - accuracy: 0.5749 - val_loss: 1.6360 - val_accuracy: 0.4400
# Epoch 18/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1279 - accuracy: 0.5980 - val_loss: 1.6043 - val_accuracy: 0.4493
# Epoch 19/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1009 - accuracy: 0.6066 - val_loss: 1.6155 - val_accuracy: 0.4393
# Epoch 20/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.0757 - accuracy: 0.6191 - val_loss: 1.5875 - val_accuracy: 0.4553
# Epoch 21/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.0373 - accuracy: 0.6297 - val_loss: 1.6730 - val_accuracy: 0.4460
# Execution time: 20.787718534469604 s

# %% [markdown]
# ❓ **Question** ❓ Run the following function on the previous history (keep the default arguments, these are intended for future plots in the notebook).

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label='train' + exp_name)
    ax1.plot(history.history['val_loss'], label='val' + exp_name)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

plot_history(history)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7feb1c3dce20>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7feb1c3953d0>)

# %% [markdown]
# ❓ **Question** ❓ Evaluate your model on the test data and compare it with baseline. Are you satisfied with these performances ? Look at PRO TIPS above and iterate a bit if you want to improve!

# %%
res = model.evaluate(X_test_small, y_test_small)[1]
print(f"Model accuracy: {res*100}%")
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 1.5324 - accuracy: 0.4730
# Model accuracy: 47.29999899864197%

# %% [markdown]
# As it stands, the model's performance aren't that great. Let change the structure of the model to find out wether we can improve the accuracy:

# %%
def initialize_better_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    model = Sequential()
    ### First convolution & max-pooling
    model.add(Conv2D(32, 3, input_shape=(32, 32, 3), activation="relu", padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    ### Second convolution & max-pooling
    model.add(Conv2D(64, 3, activation="relu", padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    ### Third convolution
    model.add(Conv2D(128, 2, activation="relu", padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    ### Flattening
    model.add(Flatten())

    ### One fully connected
    model.add(Dense(50, activation="relu"))

    ### Last layer (let's say a classification with 10 output)
    model.add(Dense(10, activation="softmax"))
    
    return model

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True) 
model = initialize_better_model() 
model = compile_model(model) 
print(model.summary())

t1 = time.time() 
history = model.fit(X_train_small, 
                    y_train_small, 
                    batch_size=32, 
                    epochs=100, 
                    validation_split=0.1, 
                    callbacks=[callback], 
                    verbose=1)

t2 = time.time() 
print(f"Execution time: {t2-t1} s")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 128)         32896
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 50)                102450
#
#  dense_5 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 155,248
# Trainable params: 155,248
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 [==============================] - 1s 6ms/step - loss: 2.1559 - accuracy: 0.1967 - val_loss: 1.8848 - val_accuracy: 0.3260
# Epoch 2/100
# 141/141 [==============================] - 1s 5ms/step - loss: 1.7477 - accuracy: 0.3656 - val_loss: 1.7039 - val_accuracy: 0.3800
# Epoch 3/100
# 141/141 [==============================] - 1s 5ms/step - loss: 1.6107 - accuracy: 0.4089 - val_loss: 1.6589 - val_accuracy: 0.4120
# Epoch 4/100
# 141/141 [==============================] - 1s 4ms/step - loss: 1.5098 - accuracy: 0.4478 - val_loss: 1.5752 - val_accuracy: 0.4360
# Epoch 5/100
# 141/141 [==============================] - 1s 4ms/step - loss: 1.3881 - accuracy: 0.4944 - val_loss: 1.5230 - val_accuracy: 0.4860
# Epoch 6/100
# 141/141 [==============================] - 1s 4ms/step - loss: 1.3046 - accuracy: 0.5280 - val_loss: 1.4074 - val_accuracy: 0.4880
# Epoch 7/100
# 141/141 [==============================] - 1s 5ms/step - loss: 1.1864 - accuracy: 0.5758 - val_loss: 1.4090 - val_accuracy: 0.4960
# Epoch 8/100
# 141/141 [==============================] - 1s 4ms/step - loss: 1.1001 - accuracy: 0.6084 - val_loss: 1.4381 - val_accuracy: 0.5000
# Epoch 9/100
# 141/141 [==============================] - 1s 4ms/step - loss: 1.0265 - accuracy: 0.6276 - val_loss: 1.3467 - val_accuracy: 0.5320
# Epoch 10/100
# 141/141 [==============================] - 1s 4ms/step - loss: 0.9521 - accuracy: 0.6627 - val_loss: 1.3845 - val_accuracy: 0.5420
# Epoch 11/100
# 141/141 [==============================] - 1s 5ms/step - loss: 0.8592 - accuracy: 0.6951 - val_loss: 1.3935 - val_accuracy: 0.5400
# Epoch 12/100
# 141/141 [==============================] - 1s 4ms/step - loss: 0.8032 - accuracy: 0.7204 - val_loss: 1.3832 - val_accuracy: 0.5340
# Epoch 13/100
# 141/141 [==============================] - 1s 4ms/step - loss: 0.7222 - accuracy: 0.7438 - val_loss: 1.4975 - val_accuracy: 0.5140
# Epoch 14/100
# 141/141 [==============================] - 1s 4ms/step - loss: 0.6523 - accuracy: 0.7780 - val_loss: 1.3978 - val_accuracy: 0.5500
# Execution time: 9.60029935836792 s

# %%
plot_history(history)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7feb1c0a9910>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7feb067534f0>)

# %%
res = model.evaluate(X_test_small, y_test_small)[1]
print(f"Model accuracy: {res*100}%")
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 1.2490 - accuracy: 0.5460
# Model accuracy: 54.60000038146973%

# %% [markdown]
# ## 3. Increase data size

# %% [markdown]
# ❓ **Question** ❓ Now that your model fits on a small subsample, try to fit it on the full dataset and notice how performance increases.
#
# 🚨 **Make sure to use GPU acceleration** by clicking on `"Runtime --> Change runtime --> GPU"` if you are on Colab.
#
# 💡 Training neural network on images (in each batch) can be parallelized, and this parallelization procedure can be done on GPU.

# %%
callback = EarlyStopping(patience=5, restore_best_weights=True) 
model = initialize_better_model() 
model = compile_model(model) 
print(model.summary())

t1 = time.time() 
history = model.fit(X_train, 
                    y_train, 
                    batch_size=32, 
                    epochs=100, 
                    validation_split=0.1, 
                    callbacks=[callback], 
                    verbose=1)

t2 = time.time() 
print(f"Execution time: {t2-t1} s")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 128)         32896
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 50)                102450
#
#  dense_7 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 155,248
# Trainable params: 155,248
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.5352 - accuracy: 0.4416 - val_loss: 1.2224 - val_accuracy: 0.5644
# Epoch 2/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1337 - accuracy: 0.5996 - val_loss: 1.0641 - val_accuracy: 0.6220
# Epoch 3/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.9694 - accuracy: 0.6593 - val_loss: 0.9366 - val_accuracy: 0.6704
# Epoch 4/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.8660 - accuracy: 0.6987 - val_loss: 0.9028 - val_accuracy: 0.6820
# Epoch 5/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.7859 - accuracy: 0.7248 - val_loss: 0.8397 - val_accuracy: 0.7114
# Epoch 6/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.7229 - accuracy: 0.7463 - val_loss: 0.8047 - val_accuracy: 0.7256
# Epoch 7/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.6599 - accuracy: 0.7714 - val_loss: 0.8141 - val_accuracy: 0.7208
# Epoch 8/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.6135 - accuracy: 0.7860 - val_loss: 0.7848 - val_accuracy: 0.7340
# Epoch 9/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.5745 - accuracy: 0.8004 - val_loss: 0.8458 - val_accuracy: 0.7226
# Epoch 10/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.5298 - accuracy: 0.8145 - val_loss: 0.8282 - val_accuracy: 0.7340
# Epoch 11/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.4977 - accuracy: 0.8233 - val_loss: 0.8472 - val_accuracy: 0.7304
# Epoch 12/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.4644 - accuracy: 0.8355 - val_loss: 0.8176 - val_accuracy: 0.7496
# Epoch 13/100
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.4346 - accuracy: 0.8456 - val_loss: 0.8569 - val_accuracy: 0.7396
# Execution time: 82.90251421928406 s

# %%
plot_history(history)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7feb066e1f40>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7feb065182e0>)

# %%
res = model.evaluate(X_test, y_test)[1]
print(f"Model accuracy: {res*100}%")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8206 - accuracy: 0.7240
# Model accuracy: 72.39999771118164%

# %% [markdown]
# ## 4. Data augmentation
#
# ☝️ It seems that adding pictures greatly improves model performance! Welcome to the Deep Learning paradigm, where big data does make a difference.
#
# To easily improve the accuracy of a model without much work, we can generate new data: the _data augmentation_. This widely used technique consists in applying little transformation to input images without changing its label, as mirroring, cropping, intensity changes, etc. The improved performance simply results from the Neural network training with more different data.
#
# The natural way to generate these new images is to apply some transformations and train the model on the original and new images. However, such procedure requires to keep all these images in memory : it can be very intensive, to the point that your computer memory cannot hold any new image (your computer might even crash).
#
# For this reason, we will augment the data **on the fly** (batch per batch), meaning that we will create new data, use them to fit the model, then delete them. Here, Keras is our friend as it provides the utils to do all this job for us. Look at the following code : the general writing can seem odd but don't be panicked: just look at the function arguments that defines the augmentation techniques that we will use and that you can check in the  [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=(0.8, 1.2),
    ) 

datagen.fit(X_train)
datagen

# %%
X_augmented_iterator = datagen.flow(X_train, shuffle=False, batch_size=1)
X_augmented_iterator

# %% [markdown]
# 💡 Always visualize your data augmentation in order to double check that you can still recognize the label yourself!

# %%
import numpy as np

for i, (raw_image, augmented_image) in enumerate(zip(X_train, X_augmented_iterator)):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2))
    ax1.imshow(raw_image)
    ax2.imshow(augmented_image[0])
    plt.show()
    
    if i > 10:
        break

# %% [markdown]
# ❗ **Remark** ❗ In this example, there is one augmented image per initial image. In fact, when your model will use `datagen.flow` in the `fit`, it will create one augmentation per epochs! Indeed, the images in the original dataset will not be provided to the optimizer, only augmented ones instead. (But because the augmentations are performed randomly, this allows both modified images and some very close of the originals).
#
# ❓ **Question** ❓ Take time to understand the cell below: Previously, we used the `validation_split` argument to let the model separate a training set from the validation one. It is not possible here as **using an image in the training set and its transformation in the validation set is considered as a data leakage**. Therefore, we have to manually define the `validation_data` with the following commands:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# The model
model_aug = initialize_model()
model_aug = compile_model(model_aug)

# The data generator
X_tr = X_train[:40000]
y_tr = y_train[:40000]
X_val = X_train[40000:]
y_val = y_train[40000:]
train_flow = datagen.flow(X_tr, y_tr, batch_size=64)

# The early stopping criterion
es = EarlyStopping(patience=3)

# The fit
history_aug = model_aug.fit(train_flow, 
                        epochs=50, 
                        callbacks=[es], 
                        validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 625/625 [==============================] - 22s 34ms/step - loss: 1.9457 - accuracy: 0.2767 - val_loss: 1.6636 - val_accuracy: 0.3883
# Epoch 2/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.6541 - accuracy: 0.3925 - val_loss: 1.5016 - val_accuracy: 0.4579
# Epoch 3/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.5533 - accuracy: 0.4311 - val_loss: 1.4633 - val_accuracy: 0.4682
# Epoch 4/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.4948 - accuracy: 0.4557 - val_loss: 1.4009 - val_accuracy: 0.4943
# Epoch 5/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.4508 - accuracy: 0.4755 - val_loss: 1.3636 - val_accuracy: 0.5192
# Epoch 6/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.4078 - accuracy: 0.4888 - val_loss: 1.3108 - val_accuracy: 0.5280
# Epoch 7/50
# 625/625 [==============================] - 22s 36ms/step - loss: 1.3789 - accuracy: 0.5032 - val_loss: 1.2758 - val_accuracy: 0.5401
# Epoch 8/50
# 625/625 [==============================] - 20s 33ms/step - loss: 1.3518 - accuracy: 0.5167 - val_loss: 1.2335 - val_accuracy: 0.5636
# Epoch 9/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.3319 - accuracy: 0.5191 - val_loss: 1.2154 - val_accuracy: 0.5705
# Epoch 10/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.3131 - accuracy: 0.5300 - val_loss: 1.2091 - val_accuracy: 0.5704
# Epoch 11/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.3023 - accuracy: 0.5312 - val_loss: 1.2337 - val_accuracy: 0.5638
# Epoch 12/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.2819 - accuracy: 0.5408 - val_loss: 1.1635 - val_accuracy: 0.5899
# Epoch 13/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.2758 - accuracy: 0.5419 - val_loss: 1.1670 - val_accuracy: 0.5864
# Epoch 14/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.2555 - accuracy: 0.5511 - val_loss: 1.1634 - val_accuracy: 0.5879
# Epoch 15/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.2505 - accuracy: 0.5527 - val_loss: 1.1484 - val_accuracy: 0.5915
# Epoch 16/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.2390 - accuracy: 0.5588 - val_loss: 1.1577 - val_accuracy: 0.5948
# Epoch 17/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.2276 - accuracy: 0.5620 - val_loss: 1.1085 - val_accuracy: 0.6106
# Epoch 18/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.2128 - accuracy: 0.5700 - val_loss: 1.0828 - val_accuracy: 0.6185
# Epoch 19/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.1968 - accuracy: 0.5732 - val_loss: 1.0799 - val_accuracy: 0.6155
# Epoch 20/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1943 - accuracy: 0.5733 - val_loss: 1.0623 - val_accuracy: 0.6303
# Epoch 21/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1830 - accuracy: 0.5803 - val_loss: 1.0764 - val_accuracy: 0.6146
# Epoch 22/50
# 625/625 [==============================] - 22s 36ms/step - loss: 1.1748 - accuracy: 0.5816 - val_loss: 1.1653 - val_accuracy: 0.6003
# Epoch 23/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1632 - accuracy: 0.5874 - val_loss: 1.0572 - val_accuracy: 0.6265
# Epoch 24/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1618 - accuracy: 0.5871 - val_loss: 1.0492 - val_accuracy: 0.6341
# Epoch 25/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.1527 - accuracy: 0.5910 - val_loss: 1.0482 - val_accuracy: 0.6259
# Epoch 26/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1470 - accuracy: 0.5907 - val_loss: 1.0659 - val_accuracy: 0.6245
# Epoch 27/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.1367 - accuracy: 0.5991 - val_loss: 1.0422 - val_accuracy: 0.6309
# Epoch 28/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1303 - accuracy: 0.6010 - val_loss: 1.0341 - val_accuracy: 0.6395
# Epoch 29/50
# 625/625 [==============================] - 20s 33ms/step - loss: 1.1322 - accuracy: 0.5999 - val_loss: 1.0503 - val_accuracy: 0.6364
# Epoch 30/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1247 - accuracy: 0.6028 - val_loss: 1.0617 - val_accuracy: 0.6290
# Epoch 31/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1258 - accuracy: 0.6004 - val_loss: 1.0263 - val_accuracy: 0.6367
# Epoch 32/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1249 - accuracy: 0.6024 - val_loss: 1.0418 - val_accuracy: 0.6304
# Epoch 33/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.1133 - accuracy: 0.6073 - val_loss: 1.0852 - val_accuracy: 0.6253
# Epoch 34/50
# 625/625 [==============================] - 20s 31ms/step - loss: 1.1046 - accuracy: 0.6110 - val_loss: 0.9875 - val_accuracy: 0.6543
# Epoch 35/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1027 - accuracy: 0.6120 - val_loss: 1.0323 - val_accuracy: 0.6414
# Epoch 36/50
# 625/625 [==============================] - 20s 32ms/step - loss: 1.1063 - accuracy: 0.6065 - val_loss: 1.0243 - val_accuracy: 0.6464
# Epoch 37/50
# 625/625 [==============================] - 22s 35ms/step - loss: 1.0961 - accuracy: 0.6140 - val_loss: 1.0096 - val_accuracy: 0.6461

# %% [markdown]
# ❗️❗️ Remark ❗️❗️: The training can be quite long here. Don't hesitate to go to the next exercise and gome back once in a while to finish the last questions
#
# ❓ **Question** ❓ Now, let's plot the previous and current run histories. What do you think of the data augmentation?

# %%
plot_history(history)
plot_history(history_aug)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7feb06463730>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7feb062dcb80>)

# %% [markdown]
# 💡 Data augmentation may not improve your performance easily. It strongly depends on the model architecture you used, the learning rate, the type of augmentation chosen, etc...Image classification is an art that takes lots of practice to master!
#
# 🚨 **Don't spend too much time now trying to finetune your model - you have other interesting challenge ahead**.
#
# 📚 [here is a good example of solution for future reference](https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/). They manage to get about 80% accuracy

# %% [markdown]
# ### 🏁 Congratulation 🏁
